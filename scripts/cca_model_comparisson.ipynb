# %% [markdown]
# # CCA-based model comparisson on synthetic fNIRS-EEG data

# %% [markdown]
# ## Synthetic Data
#
# Here we generate and inspect the synthetic fNIRS-EEG data. This will be the input to our multimodal models, so this space serves to explore different parameters to generate synthetic data with different characteristics.

# %%
from synthetic_dot_eeg import source_simulator, synthetic_fnirs_eeg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from synthetic_dot_eeg import source_simulator, synthetic_fnirs_eeg
#
# File ~/Documents/neurotech/ibs_lab/synthetic_DOT-EEG_pipeline/src/synthetic_dot_eeg/synthetic_fnirs_eeg.py:19
#      16 import mne
#      18 import cedalion
# ---> 19 from cedalion.vis import plot_sensitivity_matrix
#      20 from cedalion.sim import synthetic_hrf
#      21 from cedalion import units
#
# ImportError: cannot import name 'plot_sensitivity_matrix' from 'cedalion.vis' (/Users/guybrush/Documents/neurotech/cedalion/src/cedalion/vis/__init__.py)
